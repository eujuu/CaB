# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
import matplotlib.pyplot as plt
from PIL import Image

# %%
# This is needed to display the images.
# %matplotlib inline

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

# %%
# What model to download.
MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

NUM_CLASSES = 90

# %%
opener = urllib.request.URLopener()
opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
tar_file = tarfile.open(MODEL_FILE)
for file in tar_file.getmembers():
  file_name = os.path.basename(file.name)
  if 'frozen_inference_graph.pb' in file_name:
    tar_file.extract(file, os.getcwd())

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %%
from pykinect2 import PyKinectV2
from pykinect2.PyKinectV2 import *
from pykinect2 import PyKinectRuntime
from acquisitionKinect import AcquisitionKinect
from frame import Frame as Frame
import numpy as np
import cv2
import ctypes
import _ctypes
import sys
import face_recognition
import os

pykinect = PyKinectRuntime.PyKinectRuntime(PyKinectV2.FrameSourceTypes_Depth)
kinect = AcquisitionKinect()
f = Frame()

known_face_encodings = []
known_face_names = []

# Load sample pictures and learn how to recognize it.
dirname = 'face_recognition/knowns'
files = os.listdir(dirname)
for filename in files:
    name, ext = os.path.splitext(filename)
    if ext == '.jpg':
        known_face_names.append(name)
        pathname = os.path.join(dirname, filename)
        img = face_recognition.load_image_file(pathname)
        face_encoding = face_recognition.face_encodings(img)[0]
        known_face_encodings.append(face_encoding)

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

with detection_graph.as_default():
  with tf.Session(graph=detection_graph) as sess:
    while True:
        
        # --- Getting frames and drawing
        kinect.get_frame(f)
        kinect.get_color_frame()
        image_np = kinect._frameRGB
        image_depth = kinect._frameDepthQuantized 
        image_np = cv2.cvtColor(image_np, cv2.COLOR_RGBA2RGB)
        image_np = image_np[ 200:1020, 350:1780]
        image_np = cv2.resize(image_np, (512,424))
        cv2.imshow("depth", image_depth)

        # ----- Face Recognition
        # Resize frame of video to 1/4 size for faster face recognition processing
        rgb_small_frame = cv2.resize(image_np, (0, 0), fx=0.25, fy=0.25)

        # Only process every other frame of video to save time
        if process_this_frame:
            # Find all the faces and face encodings in the current frame of video
            face_locations = face_recognition.face_locations(rgb_small_frame)
            face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

            face_names = []
            for face_encoding in face_encodings:
                # See if the face is a match for the known face(s)
                distances = face_recognition.face_distance(known_face_encodings, face_encoding)
                min_value = min(distances)

                # tolerance: How much distance between faces to consider it a match. Lower is more strict.
                # 0.6 is typical best performance.
                name = "Unknown"
                if min_value < 0.9:
                    index = np.argmin(distances)
                    name = known_face_names[index]

                face_names.append(name)

        process_this_frame = not process_this_frame

        # Display the results
        for (top, right, bottom, left), name in zip(face_locations, face_names):
            # Scale back up face locations since the frame we detected in was scaled to 1/4 size
            top *= 4
            right *= 4
            bottom *= 4
            left *= 4

            # Draw a box around the face
            cv2.rectangle(image_np, (left, top), (right, bottom), (0, 0, 255), 2)
            # Draw a label with a name below the face
            cv2.rectangle(image_np, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
            font = cv2.FONT_HERSHEY_DUPLEX
            cv2.putText(image_np, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)


        # ----- Object Recognition
        # Definite input and output Tensors for detection_graph
        image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
        # Each box represents a part of the image where a particular object was detected.
        detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
        # Each score represent how level of confidence for each of the objects.
        # Score is shown on the result image, together with the class label.
        detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
        detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
        num_detections = detection_graph.get_tensor_by_name('num_detections:0')

        # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
        image_np_expanded = np.expand_dims(image_np, axis=0)
        # Actual detection.
        (boxes, scores, classes, num) = sess.run(
            [detection_boxes, detection_scores, detection_classes, num_detections],
            feed_dict={image_tensor: image_np_expanded})
        # Visualization of the results of a detection.
        vis_util.visualize_boxes_and_labels_on_image_array(
            image_np,
            np.squeeze(boxes),
            np.squeeze(classes).astype(np.int32),
            np.squeeze(scores),
            category_index,
            use_normalized_coordinates=True,
            line_thickness=8)

        # Get coordinates of detected boxes ; ymin, ymax, xmin, xmax
        coordinates = vis_util.return_coordinates(
                    image_np,
                    np.squeeze(boxes),
                    np.squeeze(classes).astype(np.int32),
                    np.squeeze(scores),
                    category_index,
                    use_normalized_coordinates=True,
                    line_thickness=8,
                    min_score_thresh=0.6)
        if coordinates is not None:

            # ----- Face Recognition
            print(face_names)
            count = 0
            for i in range(len(coordinates)):
                if coordinates[i][0] == 'person':
                    if count < len(face_names):
                        coordinates[i][0] = face_names[count]
                        count += 1

            #print(*coordinates)
            print(coordinates)
            xpoint_for_depth=[]
            ypoint_for_depth=[]

            print("object 개수:", len(coordinates))

            # Connect Color and Depth Info.
            frame = pykinect.get_last_depth_frame()
            #frameD = pykinect._depth_frame_data
            frameD = kinect.get_last_depth_frame()
            frame = frame.astype(np.uint8)
            frame = np.reshape(frame, (424, 512))
            frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2RGB)
            cv2.imshow("depth_frame", frame)

            # Take just one point : middle
            
            for i in range(len(coordinates)):

                ypoint_for_depth.append(int((coordinates[i][1]+coordinates[i][2])/2))
                xpoint_for_depth.append(int((coordinates[i][3]+coordinates[i][4])/2))

            print("ypoint_for_depth:", ypoint_for_depth)
            print("xpoint_for_depth:", xpoint_for_depth)
            

            ##output = cv2.bilateralFilter(output, 1, 150, 75)
            #cv2.imshow('KINECT Video Stream', frame)

            for i in range(len(coordinates)):
                #Pixel_Depth = frameD[((ypoint_for_depth[i] * 512) + xpoint_for_depth[i])]
                Pixel_Depth = image_depth[ypoint_for_depth[i]][xpoint_for_depth[i]]
                print("점 하나만 고려:",i+1, "번째 object의 depth value: ", Pixel_Depth)

            # Get average depth value considering all coordinate pairs. (List Version)
            '''Pixel_Depth_List = []
            Pixel_Depth_Sum = 0
            non_error_count = 0
            for i in range(len(coordinates)):
                for x in range(int(coordinates[i][3]), int(coordinates[i][4]+1)):
                    for y in range(int(coordinates[i][1]), int(coordinates[i][2]+1)):
                        Pixel_Depth_Sum += frameD[((y * 512) + x)]
                        if frameD[((y * 512) + x)] != 0:
                            non_error_count += 1

                Pixel_Depth_List.append(int(Pixel_Depth_Sum/non_error_count))

            for i in range(len(coordinates)):
                print("전체 면적 고려:", i+1, "번째 object의 depth value: ", Pixel_Depth_List[i])
            print("\n")'''

            # Get average depth value considering all coordinate pairs. (Dict Version)
            '''Pixel_Depth_Dict = {}
            Pixel_Depth_Sum = 0
            non_error_count = 0
            for i in range(len(coordinates)):

                # ----- Depth Recognition
                for x in range(int(coordinates[i][3]), int(coordinates[i][4]+1)):
                    for y in range(int(coordinates[i][1]), int(coordinates[i][2]+1)):
                        Pixel_Depth_Sum += frameD[((y * 512) + x)]
                        if frameD[((y * 512) + x)] != 0:
                            non_error_count += 1

                Pixel_Depth_Dict[coordinates[i][0]] = int(Pixel_Depth_Sum/non_error_count)

            # Compare each objects' depth. (Sorting: close -> far)
            sorted(Pixel_Depth_Dict.items(), key=lambda t : t[1])
            print(Pixel_Depth_Dict)
            print("\n")'''

            # VideoFileOutput.write(image_np)
            cv2.imshow('KINECT Color', image_np)
            cv2.waitKey(1)


        key = cv2.waitKey(1)
        if key == 27: break
# Out:
# []
# [['person', 112, 355, 58, 164, 95.96155881881714], ['surfboard', 297, 424, 64, 500, 65.38621187210083], ['person', 117, 322, 251, 465, 61.543381214141846]]
# object 개수: 3
# ypoint_for_depth: [233, 360, 219]
# xpoint_for_depth: [111, 282, 358]
# 점 하나만 고려: 1 번째 object의 depth value:  155
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  53
# []
# [['person', 129, 347, 145, 223, 97.14494943618774], ['person', 151, 356, 63, 175, 75.0015377998352]]
# object 개수: 2
# ypoint_for_depth: [238, 253]
# xpoint_for_depth: [184, 119]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# 점 하나만 고려: 2 번째 object의 depth value:  91
# []
# [['person', 116, 357, 130, 218, 97.32073545455933]]
# object 개수: 1
# ypoint_for_depth: [236]
# xpoint_for_depth: [174]
# 점 하나만 고려: 1 번째 object의 depth value:  104
# []
# [['person', 116, 352, 118, 213, 95.645010471344]]
# object 개수: 1
# ypoint_for_depth: [234]
# xpoint_for_depth: [165]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# []
# [['person', 112, 350, 110, 210, 94.91596817970276]]
# object 개수: 1
# ypoint_for_depth: [231]
# xpoint_for_depth: [160]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# []
# [['person', 110, 355, 103, 211, 93.09590458869934]]
# object 개수: 1
# ypoint_for_depth: [232]
# xpoint_for_depth: [157]
# 점 하나만 고려: 1 번째 object의 depth value:  116
# []
# [['person', 111, 352, 100, 202, 87.6528799533844]]
# object 개수: 1
# ypoint_for_depth: [231]
# xpoint_for_depth: [151]
# 점 하나만 고려: 1 번째 object의 depth value:  114
# []
# [['person', 110, 350, 91, 207, 86.50906085968018]]
# object 개수: 1
# ypoint_for_depth: [230]
# xpoint_for_depth: [149]
# 점 하나만 고려: 1 번째 object의 depth value:  105
# []
# [['person', 109, 352, 87, 212, 85.6887936592102]]
# object 개수: 1
# ypoint_for_depth: [230]
# xpoint_for_depth: [149]
# 점 하나만 고려: 1 번째 object의 depth value:  100
# []
# [['person', 111, 357, 76, 209, 91.86334609985352]]
# object 개수: 1
# ypoint_for_depth: [234]
# xpoint_for_depth: [142]
# 점 하나만 고려: 1 번째 object의 depth value:  100
# []
# [['person', 110, 359, 68, 189, 98.42042922973633]]
# object 개수: 1
# ypoint_for_depth: [234]
# xpoint_for_depth: [128]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# []
# [['person', 114, 356, 64, 175, 97.35830426216125]]
# object 개수: 1
# ypoint_for_depth: [235]
# xpoint_for_depth: [119]
# 점 하나만 고려: 1 번째 object의 depth value:  102
# []
# [['person', 115, 356, 62, 163, 94.86864805221558]]
# object 개수: 1
# ypoint_for_depth: [235]
# xpoint_for_depth: [112]
# 점 하나만 고려: 1 번째 object의 depth value:  106
# []
# [['person', 115, 356, 60, 166, 95.1079249382019]]
# object 개수: 1
# ypoint_for_depth: [235]
# xpoint_for_depth: [113]
# 점 하나만 고려: 1 번째 object의 depth value:  112
# []
# [['person', 116, 357, 59, 169, 95.38958072662354], ['surfboard', 298, 423, 48, 505, 61.051833629608154]]
# object 개수: 2
# ypoint_for_depth: [236, 360]
# xpoint_for_depth: [114, 276]
# 점 하나만 고려: 1 번째 object의 depth value:  116
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 119, 360, 59, 171, 94.83779072761536], ['surfboard', 298, 423, 60, 502, 61.974990367889404]]
# object 개수: 2
# ypoint_for_depth: [239, 360]
# xpoint_for_depth: [115, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 118, 358, 58, 176, 90.25537967681885]]
# object 개수: 1
# ypoint_for_depth: [238]
# xpoint_for_depth: [117]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# []
# [['person', 116, 359, 56, 183, 94.42849159240723]]
# object 개수: 1
# ypoint_for_depth: [237]
# xpoint_for_depth: [119]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# []
# [['person', 110, 361, 53, 184, 96.035635471344]]
# object 개수: 1
# ypoint_for_depth: [235]
# xpoint_for_depth: [118]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# []
# [['person', 108, 362, 58, 195, 96.55030369758606]]
# object 개수: 1
# ypoint_for_depth: [235]
# xpoint_for_depth: [126]
# 점 하나만 고려: 1 번째 object의 depth value:  115
# []
# [['person', 103, 363, 59, 193, 94.94175910949707]]
# object 개수: 1
# ypoint_for_depth: [233]
# xpoint_for_depth: [126]
# 점 하나만 고려: 1 번째 object의 depth value:  109
# []
# [['person', 106, 361, 59, 195, 94.9252188205719]]
# object 개수: 1
# ypoint_for_depth: [233]
# xpoint_for_depth: [127]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# []
# [['person', 104, 363, 61, 196, 95.14794945716858]]
# object 개수: 1
# ypoint_for_depth: [233]
# xpoint_for_depth: [128]
# 점 하나만 고려: 1 번째 object의 depth value:  99
# []
# [['person', 88, 359, 64, 196, 92.82195568084717]]
# object 개수: 1
# ypoint_for_depth: [223]
# xpoint_for_depth: [130]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# []
# [['person', 87, 347, 64, 205, 83.92910361289978]]
# object 개수: 1
# ypoint_for_depth: [217]
# xpoint_for_depth: [134]
# 점 하나만 고려: 1 번째 object의 depth value:  108
# []
# [['person', 94, 365, 57, 213, 85.00838279724121]]
# object 개수: 1
# ypoint_for_depth: [229]
# xpoint_for_depth: [135]
# 점 하나만 고려: 1 번째 object의 depth value:  110
# []
# [['person', 97, 364, 55, 209, 87.8300428390503]]
# object 개수: 1
# ypoint_for_depth: [230]
# xpoint_for_depth: [132]
# 점 하나만 고려: 1 번째 object의 depth value:  111
# []
# [['person', 92, 360, 54, 208, 90.39194583892822], ['person', 93, 331, 253, 492, 76.45544409751892]]
# object 개수: 2
# ypoint_for_depth: [226, 212]
# xpoint_for_depth: [131, 372]
# 점 하나만 고려: 1 번째 object의 depth value:  110
# 점 하나만 고려: 2 번째 object의 depth value:  59
# []
# [['person', 92, 357, 58, 200, 86.93845272064209], ['person', 86, 331, 259, 507, 70.43187022209167], ['surfboard', 297, 423, 69, 500, 67.26407408714294]]
# object 개수: 3
# ypoint_for_depth: [224, 208, 360]
# xpoint_for_depth: [129, 383, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  106
# 점 하나만 고려: 2 번째 object의 depth value:  61
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 83, 355, 62, 203, 84.63525772094727], ['surfboard', 298, 424, 66, 500, 70.5136239528656], ['person', 84, 338, 275, 501, 69.25160884857178]]
# object 개수: 3
# ypoint_for_depth: [219, 361, 211]
# xpoint_for_depth: [132, 283, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  99
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  63
# []
# [['person', 76, 353, 55, 220, 89.5625114440918], ['person', 81, 340, 265, 508, 83.81530046463013], ['surfboard', 298, 423, 60, 501, 65.7053291797638]]
# object 개수: 3
# ypoint_for_depth: [214, 210, 360]
# xpoint_for_depth: [137, 386, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  89
# 점 하나만 고려: 2 번째 object의 depth value:  57
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 59, 332, 257, 510, 82.94662237167358], ['person', 73, 356, 58, 211, 80.61255812644958]]
# object 개수: 2
# ypoint_for_depth: [195, 214]
# xpoint_for_depth: [383, 134]
# 점 하나만 고려: 1 번째 object의 depth value:  44
# 점 하나만 고려: 2 번째 object의 depth value:  81
# []
# [['person', 66, 357, 60, 215, 79.2408287525177], ['person', 41, 361, 259, 510, 67.38729476928711], ['surfboard', 298, 423, 62, 499, 64.46608304977417]]
# object 개수: 3
# ypoint_for_depth: [211, 201, 360]
# xpoint_for_depth: [137, 384, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  81
# 점 하나만 고려: 2 번째 object의 depth value:  32
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 57, 363, 55, 222, 92.66195297241211], ['person', 20, 348, 264, 510, 75.27800798416138], ['surfboard', 296, 423, 56, 499, 65.43865203857422]]
# object 개수: 3
# ypoint_for_depth: [210, 184, 359]
# xpoint_for_depth: [138, 387, 277]
# 점 하나만 고려: 1 번째 object의 depth value:  84
# 점 하나만 고려: 2 번째 object의 depth value:  38
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 64, 367, 50, 209, 93.20592880249023], ['person', 5, 345, 273, 512, 70.34798264503479], ['surfboard', 294, 424, 59, 497, 67.95343160629272]]
# object 개수: 3
# ypoint_for_depth: [215, 175, 359]
# xpoint_for_depth: [129, 392, 278]
# 점 하나만 고려: 1 번째 object의 depth value:  85
# 점 하나만 고려: 2 번째 object의 depth value:  31
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 71, 363, 53, 201, 91.98427200317383], ['person', 2, 348, 272, 512, 64.6479070186615]]
# object 개수: 2
# ypoint_for_depth: [217, 175]
# xpoint_for_depth: [127, 392]
# 점 하나만 고려: 1 번째 object의 depth value:  87
# 점 하나만 고려: 2 번째 object의 depth value:  21
# []
# [['person', 69, 360, 53, 189, 93.07796955108643], ['person', 3, 346, 271, 512, 63.621485233306885]]
# object 개수: 2
# ypoint_for_depth: [214, 174]
# xpoint_for_depth: [121, 391]
# 점 하나만 고려: 1 번째 object의 depth value:  86
# 점 하나만 고려: 2 번째 object의 depth value:  16
# []
# [['person', 65, 355, 57, 190, 95.4832911491394], ['person', 0, 355, 267, 510, 64.8007869720459]]
# object 개수: 2
# ypoint_for_depth: [210, 177]
# xpoint_for_depth: [123, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  83
# 점 하나만 고려: 2 번째 object의 depth value:  12
# []
# [['person', 57, 355, 58, 188, 95.59327363967896], ['person', 1, 355, 266, 508, 65.22661447525024]]
# object 개수: 2
# ypoint_for_depth: [206, 178]
# xpoint_for_depth: [123, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  80
# 점 하나만 고려: 2 번째 object의 depth value:  11
# []
# [['person', 44, 363, 58, 188, 91.63768291473389]]
# object 개수: 1
# ypoint_for_depth: [203]
# xpoint_for_depth: [123]
# 점 하나만 고려: 1 번째 object의 depth value:  75
# []
# [['person', 43, 360, 59, 179, 84.46287512779236], ['person', 4, 348, 272, 511, 63.05287480354309]]
# object 개수: 2
# ypoint_for_depth: [201, 176]
# xpoint_for_depth: [119, 391]
# 점 하나만 고려: 1 번째 object의 depth value:  69
# 점 하나만 고려: 2 번째 object의 depth value:  18
# []
# [['person', 41, 352, 62, 181, 86.39265298843384], ['person', 3, 346, 270, 511, 67.36468076705933]]
# object 개수: 2
# ypoint_for_depth: [196, 174]
# xpoint_for_depth: [121, 390]
# 점 하나만 고려: 1 번째 object의 depth value:  66
# 점 하나만 고려: 2 번째 object의 depth value:  17
# []
# [['person', 40, 354, 62, 183, 79.47386503219604], ['person', 5, 346, 269, 511, 67.95357465744019]]
# object 개수: 2
# ypoint_for_depth: [197, 175]
# xpoint_for_depth: [122, 390]
# 점 하나만 고려: 1 번째 object의 depth value:  63
# 점 하나만 고려: 2 번째 object의 depth value:  15
# []
# [['person', 20, 357, 61, 187, 89.55914378166199], ['person', 5, 350, 268, 511, 68.99164319038391], ['surfboard', 295, 424, 60, 498, 63.664066791534424]]
# object 개수: 3
# ypoint_for_depth: [188, 177, 359]
# xpoint_for_depth: [124, 389, 279]
# 점 하나만 고려: 1 번째 object의 depth value:  64
# 점 하나만 고려: 2 번째 object의 depth value:  14
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 35, 357, 62, 189, 93.18876266479492], ['person', 1, 359, 267, 508, 67.15272665023804], ['surfboard', 280, 420, 45, 509, 60.90793013572693]]
# object 개수: 3
# ypoint_for_depth: [196, 180, 350]
# xpoint_for_depth: [125, 387, 277]
# 점 하나만 고려: 1 번째 object의 depth value:  67
# 점 하나만 고려: 2 번째 object의 depth value:  14
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 60, 355, 65, 189, 87.72997856140137], ['person', 1, 356, 265, 508, 70.2498733997345]]
# object 개수: 2
# ypoint_for_depth: [207, 178]
# xpoint_for_depth: [127, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  76
# 점 하나만 고려: 2 번째 object의 depth value:  15
# []
# [['person', 62, 360, 56, 200, 88.43268156051636], ['person', 1, 358, 265, 508, 70.2845811843872]]
# object 개수: 2
# ypoint_for_depth: [211, 179]
# xpoint_for_depth: [128, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  83
# 점 하나만 고려: 2 번째 object의 depth value:  18
# []
# [['person', 66, 361, 57, 201, 91.41753911972046], ['person', 0, 358, 265, 508, 69.50222253799438]]
# object 개수: 2
# ypoint_for_depth: [213, 179]
# xpoint_for_depth: [129, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  87
# 점 하나만 고려: 2 번째 object의 depth value:  19
# []
# [['person', 55, 352, 61, 201, 91.01591110229492], ['person', 2, 362, 264, 508, 64.64570760726929]]
# object 개수: 2
# ypoint_for_depth: [203, 182]
# xpoint_for_depth: [131, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  88
# 점 하나만 고려: 2 번째 object의 depth value:  18
# []
# [['person', 57, 352, 63, 205, 92.33161211013794], ['person', 2, 362, 265, 508, 66.00938439369202]]
# object 개수: 2
# ypoint_for_depth: [204, 182]
# xpoint_for_depth: [134, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  91
# 점 하나만 고려: 2 번째 object의 depth value:  19
# []
# [['person', 72, 354, 61, 224, 84.01787281036377], ['person', 3, 351, 269, 512, 69.17206048965454]]
# object 개수: 2
# ypoint_for_depth: [213, 177]
# xpoint_for_depth: [142, 390]
# 점 하나만 고려: 1 번째 object의 depth value:  98
# 점 하나만 고려: 2 번째 object의 depth value:  19
# []
# [['person', 81, 357, 62, 225, 72.37526774406433], ['person', 4, 350, 268, 512, 68.85801553726196], ['surfboard', 295, 423, 60, 501, 60.75137257575989]]
# object 개수: 3
# ypoint_for_depth: [219, 177, 359]
# xpoint_for_depth: [143, 390, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 0, 344, 270, 512, 66.46672487258911], ['person', 83, 357, 62, 220, 65.89739322662354], ['surfboard', 295, 423, 62, 501, 64.80029821395874]]
# object 개수: 3
# ypoint_for_depth: [172, 220, 359]
# xpoint_for_depth: [391, 141, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  19
# 점 하나만 고려: 2 번째 object의 depth value:  106
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 89, 355, 61, 201, 86.6712749004364], ['person', 1, 363, 267, 508, 63.92416954040527], ['surfboard', 295, 424, 64, 501, 61.31005883216858]]
# object 개수: 3
# ypoint_for_depth: [222, 182, 359]
# xpoint_for_depth: [131, 387, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  111
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 93, 354, 59, 188, 93.69521737098694], ['person', 1, 360, 265, 508, 69.54793930053711], ['surfboard', 296, 424, 63, 501, 64.53006863594055]]
# object 개수: 3
# ypoint_for_depth: [223, 180, 360]
# xpoint_for_depth: [123, 386, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  114
# 점 하나만 고려: 2 번째 object의 depth value:  20
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 100, 358, 58, 191, 96.12963795661926], ['person', 1, 362, 264, 508, 66.83089137077332], ['surfboard', 296, 423, 59, 500, 63.09508681297302]]
# object 개수: 3
# ypoint_for_depth: [229, 181, 359]
# xpoint_for_depth: [124, 386, 279]
# 점 하나만 고려: 1 번째 object의 depth value:  116
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 103, 359, 57, 194, 94.58086490631104], ['person', 0, 360, 264, 508, 68.91193389892578]]
# object 개수: 2
# ypoint_for_depth: [231, 180]
# xpoint_for_depth: [125, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  20
# []
# [['person', 107, 360, 56, 186, 95.72054147720337], ['person', 0, 360, 264, 508, 69.31860446929932], ['surfboard', 296, 424, 52, 502, 62.350159883499146]]
# object 개수: 3
# ypoint_for_depth: [233, 180, 360]
# xpoint_for_depth: [121, 386, 277]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 107, 360, 59, 180, 93.46199035644531], ['person', 0, 360, 264, 508, 68.32522749900818]]
# object 개수: 2
# ypoint_for_depth: [233, 180]
# xpoint_for_depth: [119, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  19
# []
# [['person', 107, 361, 57, 178, 94.25988793373108], ['person', 1, 359, 262, 507, 69.7668194770813], ['surfboard', 296, 424, 58, 501, 67.08225011825562]]
# object 개수: 3
# ypoint_for_depth: [234, 180, 360]
# xpoint_for_depth: [117, 384, 279]
# 점 하나만 고려: 1 번째 object의 depth value:  126
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 101, 360, 58, 178, 94.66288089752197], ['surfboard', 296, 424, 59, 500, 65.08399844169617], ['person', 1, 370, 263, 511, 61.42333149909973]]
# object 개수: 3
# ypoint_for_depth: [230, 360, 185]
# xpoint_for_depth: [118, 279, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  127
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 98, 361, 58, 179, 95.45363187789917], ['surfboard', 295, 424, 55, 501, 67.17303395271301], ['person', 1, 369, 263, 511, 61.78749203681946]]
# object 개수: 3
# ypoint_for_depth: [229, 359, 185]
# xpoint_for_depth: [118, 278, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  126
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 96, 359, 58, 179, 95.12490034103394], ['person', 2, 366, 263, 510, 64.22594785690308], ['surfboard', 296, 424, 56, 500, 62.884366512298584]]
# object 개수: 3
# ypoint_for_depth: [227, 184, 360]
# xpoint_for_depth: [118, 386, 278]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  19
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 94, 359, 57, 180, 93.74285340309143], ['person', 0, 358, 263, 507, 67.95564889907837], ['surfboard', 295, 424, 59, 500, 62.8003716468811]]
# object 개수: 3
# ypoint_for_depth: [226, 179, 359]
# xpoint_for_depth: [118, 385, 279]
# 점 하나만 고려: 1 번째 object의 depth value:  124
# 점 하나만 고려: 2 번째 object의 depth value:  20
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 93, 359, 56, 181, 91.94940328598022], ['person', 0, 347, 264, 512, 66.05261564254761], ['surfboard', 295, 424, 60, 500, 64.76693749427795]]
# object 개수: 3
# ypoint_for_depth: [226, 173, 359]
# xpoint_for_depth: [118, 388, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  18
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 90, 358, 57, 181, 90.6764268875122], ['surfboard', 296, 424, 61, 502, 67.37750768661499], ['person', 1, 362, 264, 508, 63.47993016242981]]
# object 개수: 3
# ypoint_for_depth: [224, 360, 181]
# xpoint_for_depth: [119, 281, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 89, 359, 56, 180, 94.18181777000427], ['surfboard', 296, 424, 64, 502, 71.18481397628784], ['person', 0, 346, 262, 512, 64.31155204772949]]
# object 개수: 3
# ypoint_for_depth: [224, 360, 173]
# xpoint_for_depth: [118, 283, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 89, 359, 55, 181, 95.27048468589783], ['surfboard', 296, 424, 61, 501, 67.23008155822754], ['person', 0, 347, 263, 512, 64.98144865036011]]
# object 개수: 3
# ypoint_for_depth: [224, 360, 173]
# xpoint_for_depth: [118, 281, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 89, 359, 55, 181, 94.70427632331848], ['surfboard', 295, 424, 61, 502, 64.9751365184784], ['person', 1, 361, 262, 508, 63.45624327659607]]
# object 개수: 3
# ypoint_for_depth: [224, 359, 181]
# xpoint_for_depth: [118, 281, 385]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 90, 358, 55, 179, 94.74951028823853], ['surfboard', 295, 424, 63, 501, 67.15222597122192], ['person', 0, 344, 265, 512, 67.05206036567688]]
# object 개수: 3
# ypoint_for_depth: [224, 359, 172]
# xpoint_for_depth: [117, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 88, 358, 55, 179, 92.92678833007812], ['person', 0, 345, 267, 512, 66.64939522743225], ['surfboard', 295, 424, 65, 500, 66.49527549743652]]
# object 개수: 3
# ypoint_for_depth: [223, 172, 359]
# xpoint_for_depth: [117, 389, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  18
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 87, 359, 54, 181, 91.79160594940186], ['surfboard', 295, 424, 64, 501, 64.23562169075012], ['person', 0, 347, 265, 512, 61.792707443237305]]
# object 개수: 3
# ypoint_for_depth: [223, 359, 173]
# xpoint_for_depth: [117, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 88, 359, 54, 180, 93.14229488372803], ['surfboard', 295, 424, 67, 500, 67.42956638336182], ['person', 1, 362, 263, 508, 62.693339586257935]]
# object 개수: 3
# ypoint_for_depth: [223, 359, 181]
# xpoint_for_depth: [117, 283, 385]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 88, 360, 55, 180, 91.94020628929138], ['surfboard', 296, 424, 63, 501, 66.49476289749146], ['person', 4, 356, 261, 511, 62.632209062576294]]
# object 개수: 3
# ypoint_for_depth: [224, 360, 180]
# xpoint_for_depth: [117, 282, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 89, 360, 56, 179, 91.19195342063904], ['surfboard', 296, 424, 64, 501, 68.48252415657043]]
# object 개수: 2
# ypoint_for_depth: [224, 360]
# xpoint_for_depth: [117, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 89, 360, 56, 178, 92.32298135757446], ['surfboard', 295, 424, 65, 501, 67.4817442893982], ['person', 4, 358, 263, 511, 62.190258502960205]]
# object 개수: 3
# ypoint_for_depth: [224, 359, 181]
# xpoint_for_depth: [117, 283, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 88, 360, 56, 178, 91.7434573173523], ['surfboard', 295, 424, 61, 502, 67.3884928226471], ['person', 4, 352, 264, 511, 64.93140459060669]]
# object 개수: 3
# ypoint_for_depth: [224, 359, 178]
# xpoint_for_depth: [117, 281, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 91, 360, 57, 177, 90.67035913467407], ['surfboard', 295, 424, 64, 501, 66.33954048156738], ['person', 4, 357, 265, 511, 62.491875886917114]]
# object 개수: 3
# ypoint_for_depth: [225, 359, 180]
# xpoint_for_depth: [117, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 93, 371, 57, 176, 91.74388647079468], ['surfboard', 296, 424, 63, 500, 66.33139848709106], ['person', 3, 357, 265, 511, 62.39895820617676]]
# object 개수: 3
# ypoint_for_depth: [232, 360, 180]
# xpoint_for_depth: [116, 281, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 94, 369, 58, 175, 89.40054178237915], ['surfboard', 296, 424, 64, 501, 66.67740941047668], ['person', 3, 353, 265, 511, 61.02588772773743]]
# object 개수: 3
# ypoint_for_depth: [231, 360, 178]
# xpoint_for_depth: [116, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 95, 360, 59, 176, 92.35506057739258], ['surfboard', 295, 424, 63, 500, 66.53093099594116], ['person', 0, 365, 261, 508, 60.03078818321228]]
# object 개수: 3
# ypoint_for_depth: [227, 359, 182]
# xpoint_for_depth: [117, 281, 384]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 96, 360, 58, 177, 91.22158288955688], ['surfboard', 295, 424, 63, 500, 66.78793430328369], ['person', 4, 357, 264, 511, 61.52496337890625]]
# object 개수: 3
# ypoint_for_depth: [228, 359, 180]
# xpoint_for_depth: [117, 281, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 95, 360, 59, 177, 90.5252754688263], ['surfboard', 296, 424, 60, 500, 64.98671770095825], ['person', 1, 363, 262, 508, 62.1109664440155]]
# object 개수: 3
# ypoint_for_depth: [227, 360, 182]
# xpoint_for_depth: [118, 280, 385]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 95, 360, 59, 177, 89.95028138160706], ['surfboard', 295, 424, 64, 500, 65.29865264892578], ['person', 4, 353, 264, 511, 61.77127957344055]]
# object 개수: 3
# ypoint_for_depth: [227, 359, 178]
# xpoint_for_depth: [118, 282, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  21
# []
# [['person', 95, 360, 59, 178, 90.29995799064636], ['surfboard', 296, 424, 59, 501, 64.03621435165405], ['person', 4, 360, 261, 511, 60.69442629814148]]
# object 개수: 3
# ypoint_for_depth: [227, 360, 182]
# xpoint_for_depth: [118, 280, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  125
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  22
# []
# [['person', 95, 360, 59, 179, 90.04606008529663], ['surfboard', 296, 424, 61, 501, 64.46571350097656]]
# object 개수: 2
# ypoint_for_depth: [227, 360]
# xpoint_for_depth: [119, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  124
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 95, 360, 59, 179, 90.12141227722168], ['person', 2, 357, 266, 509, 68.45844984054565], ['surfboard', 296, 424, 62, 501, 65.91606736183167]]
# object 개수: 3
# ypoint_for_depth: [227, 179, 360]
# xpoint_for_depth: [119, 387, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  124
# 점 하나만 고려: 2 번째 object의 depth value:  25
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 94, 362, 59, 179, 90.96200466156006], ['surfboard', 296, 424, 65, 501, 70.13573050498962], ['person', 2, 356, 264, 509, 68.82907152175903]]
# object 개수: 3
# ypoint_for_depth: [228, 360, 179]
# xpoint_for_depth: [119, 283, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  28
# []
# [['person', 95, 361, 59, 178, 91.28835201263428], ['person', 3, 359, 265, 509, 67.36221313476562], ['surfboard', 296, 424, 66, 501, 64.58064913749695]]
# object 개수: 3
# ypoint_for_depth: [228, 181, 360]
# xpoint_for_depth: [118, 387, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  124
# 점 하나만 고려: 2 번째 object의 depth value:  29
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 371, 57, 176, 91.19977951049805], ['surfboard', 296, 424, 63, 501, 65.38079380989075], ['person', 0, 353, 269, 508, 64.66104388237]]
# object 개수: 3
# ypoint_for_depth: [233, 360, 176]
# xpoint_for_depth: [116, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  30
# []
# [['person', 93, 371, 58, 178, 90.9090518951416], ['person', 0, 340, 266, 502, 74.48537945747375]]
# object 개수: 2
# ypoint_for_depth: [232, 170]
# xpoint_for_depth: [118, 384]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  30
# []
# [['person', 95, 361, 59, 178, 90.09003639221191], ['surfboard', 297, 424, 63, 501, 74.57228899002075]]
# object 개수: 2
# ypoint_for_depth: [228, 360]
# xpoint_for_depth: [118, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 95, 361, 59, 177, 90.83112478256226], ['surfboard', 298, 424, 61, 503, 72.19061851501465], ['person', 1, 355, 269, 509, 64.19376730918884]]
# object 개수: 3
# ypoint_for_depth: [228, 361, 178]
# xpoint_for_depth: [118, 282, 389]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  20
# []
# [['person', 95, 371, 58, 176, 90.32750129699707], ['surfboard', 297, 424, 63, 503, 68.2316780090332], ['person', 1, 352, 290, 510, 62.261176109313965]]
# object 개수: 3
# ypoint_for_depth: [233, 360, 176]
# xpoint_for_depth: [117, 283, 400]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  14
# []
# [['person', 95, 361, 59, 178, 90.19426107406616], ['surfboard', 296, 424, 63, 502, 68.91762614250183], ['person', 2, 356, 303, 509, 61.570435762405396]]
# object 개수: 3
# ypoint_for_depth: [228, 360, 179]
# xpoint_for_depth: [118, 282, 406]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  21
# []
# [['person', 94, 361, 59, 176, 88.84226083755493], ['surfboard', 296, 424, 67, 502, 68.36283206939697], ['person', 3, 356, 308, 510, 60.166263580322266]]
# object 개수: 3
# ypoint_for_depth: [227, 360, 179]
# xpoint_for_depth: [117, 284, 409]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 94, 361, 59, 173, 88.56419324874878], ['surfboard', 295, 424, 65, 501, 69.17752623558044], ['person', 1, 348, 311, 509, 60.61980724334717]]
# object 개수: 3
# ypoint_for_depth: [227, 359, 174]
# xpoint_for_depth: [116, 283, 410]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  16
# []
# [['person', 97, 370, 58, 171, 88.81538510322571], ['surfboard', 296, 424, 66, 501, 72.07395434379578]]
# object 개수: 2
# ypoint_for_depth: [233, 360]
# xpoint_for_depth: [114, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 95, 361, 59, 172, 89.20190334320068], ['surfboard', 296, 424, 66, 501, 73.06222915649414], ['person', 0, 350, 305, 511, 63.565438985824585]]
# object 개수: 3
# ypoint_for_depth: [228, 360, 175]
# xpoint_for_depth: [115, 283, 408]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  18
# []
# [['person', 96, 370, 58, 171, 87.3930275440216], ['surfboard', 296, 424, 66, 502, 67.14025139808655], ['person', 4, 350, 305, 511, 64.48167562484741]]
# object 개수: 3
# ypoint_for_depth: [233, 360, 177]
# xpoint_for_depth: [114, 284, 408]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  19
# []
# [['person', 97, 368, 59, 171, 88.5085940361023], ['person', 10, 346, 297, 512, 69.25718784332275], ['surfboard', 295, 424, 67, 502, 68.8372015953064]]
# object 개수: 3
# ypoint_for_depth: [232, 178, 359]
# xpoint_for_depth: [115, 404, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  22
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 370, 59, 171, 88.95060420036316], ['person', 20, 344, 290, 512, 71.20978832244873], ['surfboard', 295, 424, 66, 502, 70.6225574016571]]
# object 개수: 3
# ypoint_for_depth: [233, 182, 359]
# xpoint_for_depth: [115, 401, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  32
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 97, 369, 59, 171, 88.52605819702148], ['person', 31, 346, 270, 511, 73.82032871246338], ['surfboard', 281, 419, 58, 509, 71.31307125091553]]
# object 개수: 3
# ypoint_for_depth: [233, 188, 350]
# xpoint_for_depth: [115, 390, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  28
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 94, 361, 60, 171, 88.36818933486938], ['person', 43, 361, 264, 512, 76.76807641983032], ['surfboard', 295, 424, 63, 501, 65.59721231460571]]
# object 개수: 3
# ypoint_for_depth: [227, 202, 359]
# xpoint_for_depth: [115, 388, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  45
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 94, 361, 60, 170, 89.01244401931763], ['surfboard', 295, 423, 66, 500, 60.36525368690491]]
# object 개수: 2
# ypoint_for_depth: [227, 359]
# xpoint_for_depth: [115, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 95, 362, 60, 170, 88.0164623260498], ['person', 54, 346, 256, 511, 71.19970917701721], ['surfboard', 296, 423, 65, 501, 63.33358883857727]]
# object 개수: 3
# ypoint_for_depth: [228, 200, 359]
# xpoint_for_depth: [115, 383, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  51
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 94, 361, 60, 170, 88.46479654312134], ['person', 57, 335, 253, 511, 86.63560152053833], ['surfboard', 297, 424, 65, 501, 67.22179055213928]]
# object 개수: 3
# ypoint_for_depth: [227, 196, 360]
# xpoint_for_depth: [115, 382, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  48
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 359, 60, 169, 89.93831872940063], ['person', 62, 336, 247, 500, 89.44772481918335], ['surfboard', 298, 424, 70, 499, 72.59037494659424]]
# object 개수: 3
# ypoint_for_depth: [227, 199, 361]
# xpoint_for_depth: [114, 373, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  49
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 95, 355, 61, 167, 93.11928749084473], ['person', 60, 337, 249, 501, 89.9344265460968], ['surfboard', 297, 423, 67, 500, 68.84344816207886]]
# object 개수: 3
# ypoint_for_depth: [225, 198, 360]
# xpoint_for_depth: [114, 375, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  122
# 점 하나만 고려: 2 번째 object의 depth value:  49
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 93, 362, 54, 166, 85.5853796005249], ['person', 62, 342, 249, 507, 82.57460594177246], ['surfboard', 297, 424, 73, 500, 72.70318865776062]]
# object 개수: 3
# ypoint_for_depth: [227, 202, 360]
# xpoint_for_depth: [110, 378, 286]
# 점 하나만 고려: 1 번째 object의 depth value:  79
# 점 하나만 고려: 2 번째 object의 depth value:  49
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 93, 360, 57, 166, 86.58640384674072], ['person', 53, 341, 259, 508, 74.94606971740723], ['surfboard', 297, 424, 62, 500, 70.26125192642212]]
# object 개수: 3
# ypoint_for_depth: [226, 197, 360]
# xpoint_for_depth: [111, 383, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  117
# 점 하나만 고려: 2 번째 object의 depth value:  49
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 53, 341, 258, 510, 78.77382636070251], ['surfboard', 297, 423, 60, 500, 64.50166702270508], ['person', 107, 358, 60, 166, 60.90282201766968]]
# object 개수: 3
# ypoint_for_depth: [197, 360, 232]
# xpoint_for_depth: [384, 280, 113]
# 점 하나만 고려: 1 번째 object의 depth value:  48
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  119
# []
# [['person', 53, 341, 261, 509, 80.036461353302], ['surfboard', 298, 423, 61, 500, 67.4070954322815], ['person', 102, 360, 62, 169, 64.46698904037476]]
# object 개수: 3
# ypoint_for_depth: [197, 360, 231]
# xpoint_for_depth: [385, 280, 115]
# 점 하나만 고려: 1 번째 object의 depth value:  48
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  120
# []
# [['person', 55, 338, 257, 508, 84.34125185012817], ['surfboard', 297, 423, 60, 500, 68.87929439544678]]
# object 개수: 2
# ypoint_for_depth: [196, 360]
# xpoint_for_depth: [382, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  47
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['surfboard', 298, 424, 61, 501, 69.24463510513306]]
# object 개수: 1
# ypoint_for_depth: [361]
# xpoint_for_depth: [281]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['person', 41, 363, 265, 512, 63.513100147247314], ['surfboard', 297, 423, 59, 501, 62.707602977752686]]
# object 개수: 2
# ypoint_for_depth: [202, 360]
# xpoint_for_depth: [388, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  46
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['surfboard', 297, 424, 63, 499, 73.29818606376648]]
# object 개수: 1
# ypoint_for_depth: [360]
# xpoint_for_depth: [281]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['surfboard', 296, 424, 64, 500, 68.05905103683472], ['person', 26, 350, 276, 512, 63.87615203857422]]
# object 개수: 2
# ypoint_for_depth: [360, 188]
# xpoint_for_depth: [282, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# 점 하나만 고려: 2 번째 object의 depth value:  34
# []
# [['person', 10, 352, 274, 509, 66.52075052261353], ['surfboard', 296, 423, 67, 502, 61.47066354751587]]
# object 개수: 2
# ypoint_for_depth: [181, 359]
# xpoint_for_depth: [391, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  32
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 93, 362, 54, 168, 80.70250749588013], ['person', 2, 347, 278, 510, 74.25116896629333]]
# object 개수: 2
# ypoint_for_depth: [227, 174]
# xpoint_for_depth: [111, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  29
# []
# [['person', 94, 371, 58, 182, 86.67763471603394], ['person', 0, 346, 280, 509, 69.87816095352173]]
# object 개수: 2
# ypoint_for_depth: [232, 173]
# xpoint_for_depth: [120, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  61
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 96, 360, 59, 180, 92.29093790054321], ['person', 0, 344, 281, 509, 69.03632879257202]]
# object 개수: 2
# ypoint_for_depth: [228, 172]
# xpoint_for_depth: [119, 395]
# 점 하나만 고려: 1 번째 object의 depth value:  67
# 점 하나만 고려: 2 번째 object의 depth value:  27
# []
# [['person', 96, 353, 59, 173, 95.35278081893921], ['person', 0, 348, 280, 509, 69.0381646156311]]
# object 개수: 2
# ypoint_for_depth: [224, 174]
# xpoint_for_depth: [116, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  118
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 96, 359, 59, 171, 92.82101392745972], ['person', 1, 348, 278, 509, 64.3250823020935]]
# object 개수: 2
# ypoint_for_depth: [227, 174]
# xpoint_for_depth: [115, 393]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 96, 357, 60, 172, 93.74772906303406], ['person', 1, 349, 278, 509, 64.82370495796204]]
# object 개수: 2
# ypoint_for_depth: [226, 175]
# xpoint_for_depth: [116, 393]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 96, 359, 60, 174, 94.91906762123108], ['person', 1, 349, 278, 509, 64.40441608428955], ['surfboard', 296, 423, 62, 501, 63.002121448516846]]
# object 개수: 3
# ypoint_for_depth: [227, 175, 359]
# xpoint_for_depth: [117, 393, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  118
# 점 하나만 고려: 2 번째 object의 depth value:  28
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 97, 359, 61, 174, 95.07285356521606], ['person', 0, 348, 279, 509, 65.79936742782593]]
# object 개수: 2
# ypoint_for_depth: [228, 174]
# xpoint_for_depth: [117, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  27
# []
# [['person', 98, 359, 60, 173, 95.0568675994873], ['person', 0, 348, 277, 508, 68.7461256980896]]
# object 개수: 2
# ypoint_for_depth: [228, 174]
# xpoint_for_depth: [116, 392]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 100, 364, 58, 171, 93.5468077659607], ['person', 0, 346, 278, 509, 70.21669149398804], ['surfboard', 296, 424, 65, 501, 61.755359172821045]]
# object 개수: 3
# ypoint_for_depth: [232, 173, 360]
# xpoint_for_depth: [114, 393, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  28
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 100, 362, 59, 171, 93.70940327644348], ['person', 0, 346, 278, 508, 70.66447734832764]]
# object 개수: 2
# ypoint_for_depth: [231, 173]
# xpoint_for_depth: [115, 393]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  28
# []
# [['person', 99, 360, 59, 170, 94.73050832748413], ['person', 0, 342, 278, 509, 70.85248827934265], ['surfboard', 296, 423, 63, 501, 61.159420013427734]]
# object 개수: 3
# ypoint_for_depth: [229, 171, 359]
# xpoint_for_depth: [114, 393, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# 점 하나만 고려: 2 번째 object의 depth value:  28
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 99, 360, 58, 171, 94.04146671295166], ['person', 0, 343, 280, 509, 69.22263503074646]]
# object 개수: 2
# ypoint_for_depth: [229, 171]
# xpoint_for_depth: [114, 394]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  27
# []
# [['person', 98, 362, 60, 169, 92.59501695632935], ['person', 0, 343, 280, 509, 68.64085793495178], ['surfboard', 296, 424, 65, 501, 60.41905879974365]]
# object 개수: 3
# ypoint_for_depth: [230, 171, 360]
# xpoint_for_depth: [114, 394, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  27
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 99, 362, 59, 169, 91.53317213058472], ['person', 0, 343, 276, 508, 68.53170394897461], ['surfboard', 296, 424, 65, 501, 61.607712507247925]]
# object 개수: 3
# ypoint_for_depth: [230, 171, 360]
# xpoint_for_depth: [114, 392, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  26
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 98, 362, 59, 168, 91.35185480117798], ['person', 0, 344, 278, 508, 65.39613604545593]]
# object 개수: 2
# ypoint_for_depth: [230, 172]
# xpoint_for_depth: [113, 393]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  26
# []
# [['person', 98, 359, 60, 168, 92.94317960739136], ['person', 0, 342, 278, 508, 67.17835068702698], ['surfboard', 296, 424, 62, 501, 60.61684489250183]]
# object 개수: 3
# ypoint_for_depth: [228, 171, 360]
# xpoint_for_depth: [114, 393, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  26
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 97, 357, 61, 170, 92.17875003814697], ['person', 1, 343, 274, 508, 73.06840419769287], ['surfboard', 297, 424, 67, 498, 63.580530881881714]]
# object 개수: 3
# ypoint_for_depth: [227, 172, 360]
# xpoint_for_depth: [115, 391, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# 점 하나만 고려: 2 번째 object의 depth value:  27
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 357, 61, 171, 92.44092106819153], ['person', 1, 344, 275, 509, 71.26484513282776], ['surfboard', 297, 424, 66, 499, 62.203800678253174]]
# object 개수: 3
# ypoint_for_depth: [226, 172, 360]
# xpoint_for_depth: [116, 392, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  27
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 356, 61, 171, 92.25751161575317], ['person', 1, 344, 277, 509, 72.3004162311554], ['surfboard', 296, 424, 65, 499, 62.15919256210327]]
# object 개수: 3
# ypoint_for_depth: [226, 172, 360]
# xpoint_for_depth: [116, 393, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  28
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 357, 61, 172, 92.00670719146729], ['person', 1, 344, 274, 509, 73.08816909790039], ['surfboard', 297, 423, 64, 499, 61.7885947227478]]
# object 개수: 3
# ypoint_for_depth: [226, 172, 360]
# xpoint_for_depth: [116, 391, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  29
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 357, 60, 174, 91.81290864944458], ['person', 1, 347, 273, 509, 68.78490447998047], ['surfboard', 297, 424, 64, 500, 64.13950324058533]]
# object 개수: 3
# ypoint_for_depth: [226, 174, 360]
# xpoint_for_depth: [117, 391, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  121
# 점 하나만 고려: 2 번째 object의 depth value:  30
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 96, 356, 60, 171, 92.88446307182312], ['person', 0, 342, 277, 511, 65.2955412864685], ['surfboard', 298, 424, 63, 499, 63.136833906173706]]
# object 개수: 3
# ypoint_for_depth: [226, 171, 361]
# xpoint_for_depth: [115, 394, 281]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# 점 하나만 고려: 2 번째 object의 depth value:  30
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 97, 356, 60, 170, 92.83422827720642], ['surfboard', 297, 424, 61, 500, 61.54748797416687]]
# object 개수: 2
# ypoint_for_depth: [226, 360]
# xpoint_for_depth: [115, 280]
# 점 하나만 고려: 1 번째 object의 depth value:  120
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 98, 356, 60, 167, 94.62112784385681], ['surfboard', 297, 424, 58, 501, 66.01929664611816], ['person', 7, 353, 267, 511, 65.36927819252014]]
# object 개수: 3
# ypoint_for_depth: [227, 360, 180]
# xpoint_for_depth: [113, 279, 389]
# 점 하나만 고려: 1 번째 object의 depth value:  119
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  33
# []
# [['person', 97, 358, 59, 171, 90.40864109992981], ['surfboard', 297, 424, 66, 500, 72.02978134155273]]
# object 개수: 2
# ypoint_for_depth: [227, 360]
# xpoint_for_depth: [115, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  118
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 96, 351, 55, 170, 81.24909400939941], ['surfboard', 298, 424, 64, 501, 69.97095942497253]]
# object 개수: 2
# ypoint_for_depth: [223, 361]
# xpoint_for_depth: [112, 282]
# 점 하나만 고려: 1 번째 object의 depth value:  111
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['surfboard', 297, 424, 67, 500, 70.12293934822083]]
# object 개수: 1
# ypoint_for_depth: [360]
# xpoint_for_depth: [283]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['surfboard', 297, 424, 64, 501, 71.19754552841187]]
# object 개수: 1
# ypoint_for_depth: [360]
# xpoint_for_depth: [282]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['person', 103, 361, 61, 175, 87.30218410491943], ['surfboard', 297, 424, 69, 501, 70.9263801574707], ['person', 3, 356, 263, 509, 60.75286865234375]]
# object 개수: 3
# ypoint_for_depth: [232, 360, 179]
# xpoint_for_depth: [118, 285, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  109
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  33
# []
# [['person', 106, 361, 65, 179, 90.49596786499023], ['surfboard', 297, 424, 68, 500, 70.01620531082153]]
# object 개수: 2
# ypoint_for_depth: [233, 360]
# xpoint_for_depth: [122, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 103, 363, 65, 183, 89.23676013946533], ['surfboard', 297, 424, 68, 500, 68.12256574630737]]
# object 개수: 2
# ypoint_for_depth: [233, 360]
# xpoint_for_depth: [124, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 105, 364, 65, 184, 93.85771155357361], ['surfboard', 297, 424, 71, 499, 67.56652593612671], ['person', 2, 354, 265, 509, 62.56248950958252]]
# object 개수: 3
# ypoint_for_depth: [234, 360, 178]
# xpoint_for_depth: [124, 285, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  33
# []
# [['person', 104, 363, 67, 185, 94.94878053665161], ['surfboard', 298, 424, 66, 500, 66.2335991859436]]
# object 개수: 2
# ypoint_for_depth: [233, 361]
# xpoint_for_depth: [126, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  106
# 점 하나만 고려: 2 번째 object의 depth value:  194
# []
# [['person', 101, 361, 67, 189, 96.5904951095581], ['surfboard', 297, 424, 67, 500, 67.63904690742493], ['person', 3, 349, 268, 509, 63.44375014305115]]
# object 개수: 3
# ypoint_for_depth: [231, 360, 176]
# xpoint_for_depth: [128, 283, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  105
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  32
# []
# [['person', 104, 359, 70, 187, 94.62355375289917], ['surfboard', 297, 424, 67, 499, 65.79994559288025], ['person', 4, 353, 267, 509, 63.28526735305786]]
# object 개수: 3
# ypoint_for_depth: [231, 360, 178]
# xpoint_for_depth: [128, 283, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  32
# []
# [['person', 105, 358, 70, 187, 93.4518814086914], ['surfboard', 297, 424, 65, 499, 64.40037488937378], ['person', 3, 350, 267, 509, 64.03990983963013]]
# object 개수: 3
# ypoint_for_depth: [231, 360, 176]
# xpoint_for_depth: [128, 282, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  32
# []
# [['person', 108, 358, 69, 181, 95.78797221183777], ['person', 3, 350, 267, 509, 63.575077056884766], ['surfboard', 297, 424, 69, 499, 61.31826639175415]]
# object 개수: 3
# ypoint_for_depth: [233, 176, 360]
# xpoint_for_depth: [125, 388, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  109
# 점 하나만 고려: 2 번째 object의 depth value:  32
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 107, 358, 69, 183, 97.18387126922607], ['person', 3, 349, 267, 509, 62.64803409576416], ['surfboard', 297, 424, 68, 498, 60.98300218582153]]
# object 개수: 3
# ypoint_for_depth: [232, 176, 360]
# xpoint_for_depth: [126, 388, 283]
# 점 하나만 고려: 1 번째 object의 depth value:  108
# 점 하나만 고려: 2 번째 object의 depth value:  32
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 106, 359, 69, 184, 96.07158899307251], ['surfboard', 296, 424, 68, 499, 61.84045672416687], ['person', 3, 351, 267, 509, 61.73467040061951]]
# object 개수: 3
# ypoint_for_depth: [232, 360, 177]
# xpoint_for_depth: [126, 283, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  108
# 점 하나만 고려: 2 번째 object의 depth value:  194
# 점 하나만 고려: 3 번째 object의 depth value:  32
# []
# [['person', 105, 358, 68, 183, 95.97172141075134], ['person', 3, 347, 268, 509, 61.69320344924927]]
# object 개수: 2
# ypoint_for_depth: [231, 175]
# xpoint_for_depth: [125, 388]
# 점 하나만 고려: 1 번째 object의 depth value:  109
# 점 하나만 고려: 2 번째 object의 depth value:  31
# []
# [['person', 106, 357, 68, 178, 95.33205032348633], ['person', 2, 349, 266, 509, 62.1757447719574]]
# object 개수: 2
# ypoint_for_depth: [231, 175]
# xpoint_for_depth: [123, 387]
# 점 하나만 고려: 1 번째 object의 depth value:  110
# 점 하나만 고려: 2 번째 object의 depth value:  32
# []
# [['person', 105, 357, 69, 178, 93.60880851745605], ['person', 2, 352, 265, 508, 65.28818607330322], ['surfboard', 296, 424, 69, 499, 62.70740032196045]]
# object 개수: 3
# ypoint_for_depth: [231, 177, 360]
# xpoint_for_depth: [123, 386, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  110
# 점 하나만 고려: 2 번째 object의 depth value:  31
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 110, 357, 70, 179, 87.27841377258301], ['person', 2, 346, 265, 509, 64.07110691070557], ['surfboard', 297, 424, 70, 498, 62.61225938796997]]
# object 개수: 3
# ypoint_for_depth: [233, 174, 360]
# xpoint_for_depth: [124, 387, 284]
# 점 하나만 고려: 1 번째 object의 depth value:  109
# 점 하나만 고려: 2 번째 object의 depth value:  29
# 점 하나만 고려: 3 번째 object의 depth value:  194
# []
# [['person', 104, 356, 68, 179, 92.96410083770752], ['person', 2, 350, 265, 508, 64.97994065284729]]
# object 개수: 2
# ypoint_for_depth: [230, 176]
# xpoint_for_depth: [123, 386]
# 점 하나만 고려: 1 번째 object의 depth value:  108
# 점 하나만 고려: 2 번째 object의 depth value:  30
# []
# ...
# object 개수: 2
# ypoint_for_depth: [247, 293]
# xpoint_for_depth: [105, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  143
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 139, 358, 54, 160, 91.29787683486938], ['chair', 227, 362, 274, 339, 60.858553647994995]]
# object 개수: 2
# ypoint_for_depth: [248, 294]
# xpoint_for_depth: [107, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  146
# 점 하나만 고려: 2 번째 object의 depth value:  59
# []
# [['person', 140, 359, 53, 161, 92.89534091949463], ['chair', 227, 362, 276, 342, 64.09963369369507]]
# object 개수: 2
# ypoint_for_depth: [249, 294]
# xpoint_for_depth: [107, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  145
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 141, 358, 53, 160, 92.1301543712616], ['chair', 228, 361, 275, 341, 66.20834469795227]]
# object 개수: 2
# ypoint_for_depth: [249, 294]
# xpoint_for_depth: [106, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  144
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 141, 356, 55, 159, 91.7534589767456], ['chair', 226, 362, 274, 339, 61.76202893257141]]
# object 개수: 2
# ypoint_for_depth: [248, 294]
# xpoint_for_depth: [107, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  142
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 141, 355, 54, 153, 87.34139204025269], ['chair', 227, 362, 276, 342, 60.2481484413147]]
# object 개수: 2
# ypoint_for_depth: [248, 294]
# xpoint_for_depth: [103, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  142
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 141, 355, 54, 152, 85.97822189331055]]
# object 개수: 1
# ypoint_for_depth: [248]
# xpoint_for_depth: [103]
# 점 하나만 고려: 1 번째 object의 depth value:  143
# []
# [['person', 141, 357, 56, 146, 87.81808614730835], ['chair', 227, 362, 275, 340, 64.54956531524658]]
# object 개수: 2
# ypoint_for_depth: [249, 294]
# xpoint_for_depth: [101, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  145
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 142, 357, 57, 146, 76.99973583221436], ['chair', 226, 362, 275, 340, 63.783228397369385]]
# object 개수: 2
# ypoint_for_depth: [249, 294]
# xpoint_for_depth: [101, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  147
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 142, 358, 55, 154, 68.80108118057251], ['chair', 226, 362, 275, 340, 64.52252268791199]]
# object 개수: 2
# ypoint_for_depth: [250, 294]
# xpoint_for_depth: [104, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  146
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 153, 373, 53, 147, 75.1340389251709], ['chair', 226, 362, 274, 339, 65.85266590118408]]
# object 개수: 2
# ypoint_for_depth: [263, 294]
# xpoint_for_depth: [100, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  143
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 140, 355, 56, 145, 86.163330078125], ['chair', 226, 362, 274, 340, 64.5114541053772]]
# object 개수: 2
# ypoint_for_depth: [247, 294]
# xpoint_for_depth: [100, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  137
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 141, 353, 56, 148, 88.3545458316803], ['chair', 227, 362, 273, 339, 63.39900493621826]]
# object 개수: 2
# ypoint_for_depth: [247, 294]
# xpoint_for_depth: [102, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  131
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 142, 351, 57, 145, 86.96485161781311], ['chair', 227, 362, 273, 339, 63.93287181854248]]
# object 개수: 2
# ypoint_for_depth: [246, 294]
# xpoint_for_depth: [101, 306]
# 점 하나만 고려: 1 번째 object의 depth value:  127
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 139, 351, 55, 144, 92.39777326583862], ['chair', 227, 362, 276, 342, 63.60563039779663]]
# object 개수: 2
# ypoint_for_depth: [245, 294]
# xpoint_for_depth: [99, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  123
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 135, 353, 55, 146, 93.93683075904846], ['chair', 226, 361, 275, 340, 66.72633290290833]]
# object 개수: 2
# ypoint_for_depth: [244, 293]
# xpoint_for_depth: [100, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  118
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 131, 353, 56, 147, 93.99084448814392], ['chair', 226, 362, 277, 340, 65.99711775779724]]
# object 개수: 2
# ypoint_for_depth: [242, 294]
# xpoint_for_depth: [101, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  113
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 121, 349, 54, 151, 92.06706285476685], ['chair', 227, 362, 278, 340, 69.07802820205688]]
# object 개수: 2
# ypoint_for_depth: [235, 294]
# xpoint_for_depth: [102, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  111
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 116, 350, 54, 156, 94.11347508430481], ['chair', 227, 361, 276, 340, 66.69131517410278]]
# object 개수: 2
# ypoint_for_depth: [233, 294]
# xpoint_for_depth: [105, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  107
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 108, 354, 49, 161, 91.1110520362854], ['chair', 227, 362, 276, 340, 66.17962121963501]]
# object 개수: 2
# ypoint_for_depth: [231, 294]
# xpoint_for_depth: [105, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  103
# 점 하나만 고려: 2 번째 object의 depth value:  56
# []
# [['person', 95, 355, 48, 160, 88.94872069358826], ['chair', 227, 362, 276, 339, 69.806969165802]]
# object 개수: 2
# ypoint_for_depth: [225, 294]
# xpoint_for_depth: [104, 307]
# 점 하나만 고려: 1 번째 object의 depth value:  101
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 85, 358, 48, 162, 79.7578513622284], ['chair', 227, 362, 276, 341, 67.2791600227356]]
# object 개수: 2
# ypoint_for_depth: [221, 294]
# xpoint_for_depth: [105, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  103
# 점 하나만 고려: 2 번째 object의 depth value:  57
# []
# [['person', 87, 367, 49, 157, 69.91263031959534], ['chair', 227, 362, 278, 341, 67.8899347782135]]
# object 개수: 2
# ypoint_for_depth: [227, 294]
# xpoint_for_depth: [103, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  102
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 83, 364, 48, 150, 67.23056435585022], ['chair', 227, 362, 278, 343, 65.50737023353577]]
# object 개수: 2
# ypoint_for_depth: [223, 294]
# xpoint_for_depth: [99, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  97
# 점 하나만 고려: 2 번째 object의 depth value:  59
# []
# [['person', 70, 364, 52, 161, 78.80799770355225], ['chair', 226, 361, 276, 341, 67.0547366142273]]
# object 개수: 2
# ypoint_for_depth: [217, 293]
# xpoint_for_depth: [106, 308]
# 점 하나만 고려: 1 번째 object의 depth value:  88
# 점 하나만 고려: 2 번째 object의 depth value:  58
# []
# [['person', 62, 362, 56, 171, 91.28472208976746], ['chair', 226, 362, 277, 341, 68.86444091796875]]
# object 개수: 2
# ypoint_for_depth: [212, 294]
# xpoint_for_depth: [113, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  81
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 55, 363, 55, 175, 93.90848875045776], ['chair', 226, 361, 279, 341, 70.08532285690308]]
# object 개수: 2
# ypoint_for_depth: [209, 293]
# xpoint_for_depth: [115, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  74
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 50, 357, 56, 177, 94.5756196975708], ['chair', 226, 361, 279, 341, 68.38271021842957]]
# object 개수: 2
# ypoint_for_depth: [203, 293]
# xpoint_for_depth: [116, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  72
# 점 하나만 고려: 2 번째 object의 depth value:  61
# []
# [['person', 45, 357, 56, 178, 95.01204490661621], ['chair', 226, 361, 279, 341, 69.06900405883789]]
# object 개수: 2
# ypoint_for_depth: [201, 293]
# xpoint_for_depth: [117, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  68
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 43, 368, 59, 182, 97.31391668319702], ['chair', 226, 362, 280, 341, 69.49821710586548]]
# object 개수: 2
# ypoint_for_depth: [205, 294]
# xpoint_for_depth: [120, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  63
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 18, 367, 58, 187, 91.1131203174591], ['chair', 227, 360, 278, 340, 68.37192177772522]]
# object 개수: 2
# ypoint_for_depth: [192, 293]
# xpoint_for_depth: [122, 309]
# 점 하나만 고려: 1 번째 object의 depth value:  59
# 점 하나만 고려: 2 번째 object의 depth value:  60
# []
# [['person', 7, 372, 55, 190, 70.24608254432678], ['chair', 226, 361, 280, 340, 69.19678449630737]]
# object 개수: 2
# ypoint_for_depth: [189, 293]
# xpoint_for_depth: [122, 310]
# 점 하나만 고려: 1 번째 object의 depth value:  56
# 점 하나만 고려: 2 번째 object의 depth value:  62
# []
# [['chair', 226, 361, 278, 340, 68.60812306404114]]
# object 개수: 1
# ypoint_for_depth: [293]
# xpoint_for_depth: [309]
# 점 하나만 고려: 1 번째 object의 depth value:  60
# []
# [['chair', 226, 361, 279, 340, 67.64073371887207]]
# object 개수: 1
# ypoint_for_depth: [293]
# xpoint_for_depth: [309]
# 점 하나만 고려: 1 번째 object의 depth value:  60
# []
# [['chair', 226, 361, 282, 342, 68.11386942863464]]
# object 개수: 1
# ypoint_for_depth: [293]
# xpoint_for_depth: [312]
# 점 하나만 고려: 1 번째 object의 depth value:  62
# []
# [['chair', 226, 361, 281, 342, 67.76490807533264]]
# object 개수: 1
# ypoint_for_depth: [293]
# xpoint_for_depth: [311]
# 점 하나만 고려: 1 번째 object의 depth value:  61
# []
# [['chair', 218, 359, 280, 337, 72.4113941192627]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  61
# []
# [['chair', 225, 361, 282, 342, 75.13970136642456]]
# object 개수: 1
# ypoint_for_depth: [293]
# xpoint_for_depth: [312]
# 점 하나만 고려: 1 번째 object의 depth value:  64
# []
# [['chair', 217, 359, 280, 337, 73.13031554222107]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  60
# []
# [['chair', 217, 359, 280, 336, 76.88061594963074]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  61
# []
# [['chair', 218, 359, 280, 336, 71.38971090316772]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  59
# []
# [['chair', 218, 359, 280, 337, 75.28856992721558]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  59
# []
# [['chair', 218, 359, 279, 336, 74.87820982933044]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [307]
# 점 하나만 고려: 1 번째 object의 depth value:  58
# []
# [['chair', 218, 359, 280, 336, 72.10837006568909]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [308]
# 점 하나만 고려: 1 번째 object의 depth value:  59
# []
# [['chair', 218, 359, 280, 338, 72.95216917991638]]
# object 개수: 1
# ypoint_for_depth: [288]
# xpoint_for_depth: [309]
# 점 하나만 고려: 1 번째 object의 depth value:  62
# []
# [['chair', 224, 361, 281, 343, 68.87321472167969]]
# object 개수: 1
# ypoint_for_depth: [292]
# xpoint_for_depth: [312]
# 점 하나만 고려: 1 번째 object의 depth value:  63
# []
# [['person', 0, 377, 28, 261, 60.01219153404236]]
# object 개수: 1
# ypoint_for_depth: [188]
# xpoint_for_depth: [144]
# 점 하나만 고려: 1 번째 object의 depth value:  28
# []
# []
# object 개수: 0
# ypoint_for_depth: []
# xpoint_for_depth: []
# []
# []
# object 개수: 0
# ypoint_for_depth: []
# xpoint_for_depth: []
# []
# []
# object 개수: 0
# ypoint_for_depth: []
# xpoint_for_depth: []
# []
# [['person', 5, 369, 58, 480, 66.10857844352722]]
# object 개수: 1
# ypoint_for_depth: [187]
# xpoint_for_depth: [269]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# []
# object 개수: 0
# ypoint_for_depth: []
# xpoint_for_depth: []
# []
# [['person', 2, 422, 55, 509, 68.77126097679138]]
# object 개수: 1
# ypoint_for_depth: [212]
# xpoint_for_depth: [282]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['person', 6, 421, 49, 509, 72.69521355628967]]
# object 개수: 1
# ypoint_for_depth: [213]
# xpoint_for_depth: [279]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['person', 13, 421, 40, 507, 75.92319250106812]]
# object 개수: 1
# ypoint_for_depth: [217]
# xpoint_for_depth: [273]
# 점 하나만 고려: 1 번째 object의 depth value:  194
# []
# [['person', 5, 419, 30, 497, 75.47800540924072]]
# object 개수: 1
# ypoint_for_depth: [212]
# xpoint_for_depth: [263]
# 점 하나만 고려: 1 번째 object의 depth value:  48
# []
# [['person', 6, 402, 42, 479, 71.28039598464966]]
# object 개수: 1
# ypoint_for_depth: [204]
# xpoint_for_depth: [260]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 7, 397, 32, 441, 74.78361129760742]]
# object 개수: 1
# ypoint_for_depth: [202]
# xpoint_for_depth: [236]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 8, 394, 30, 436, 75.61111450195312]]
# object 개수: 1
# ypoint_for_depth: [201]
# xpoint_for_depth: [233]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 2, 398, 28, 452, 73.91752004623413]]
# object 개수: 1
# ypoint_for_depth: [200]
# xpoint_for_depth: [240]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 3, 399, 28, 441, 77.70717144012451]]
# object 개수: 1
# ypoint_for_depth: [201]
# xpoint_for_depth: [234]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 3, 395, 35, 451, 79.81474995613098]]
# object 개수: 1
# ypoint_for_depth: [199]
# xpoint_for_depth: [243]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 7, 387, 38, 438, 81.48785829544067]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [238]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 8, 388, 46, 419, 85.40974855422974]]
# object 개수: 1
# ypoint_for_depth: [198]
# xpoint_for_depth: [232]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 7, 390, 42, 421, 85.35939455032349]]
# object 개수: 1
# ypoint_for_depth: [198]
# xpoint_for_depth: [231]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 6, 386, 36, 403, 82.73327350616455]]
# object 개수: 1
# ypoint_for_depth: [196]
# xpoint_for_depth: [219]
# 점 하나만 고려: 1 번째 object의 depth value:  47
# []
# [['person', 7, 389, 36, 415, 81.85215592384338]]
# object 개수: 1
# ypoint_for_depth: [198]
# xpoint_for_depth: [225]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 7, 388, 39, 425, 84.12052392959595]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [232]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 7, 388, 36, 433, 78.57697606086731]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [234]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 8, 388, 39, 425, 83.27683210372925]]
# object 개수: 1
# ypoint_for_depth: [198]
# xpoint_for_depth: [232]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 8, 386, 35, 426, 79.92337942123413]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [230]
# 점 하나만 고려: 1 번째 object의 depth value:  50
# []
# [['person', 9, 385, 29, 423, 79.51613664627075]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [226]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 8, 384, 38, 431, 79.29095029830933]]
# object 개수: 1
# ypoint_for_depth: [196]
# xpoint_for_depth: [234]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 11, 384, 32, 436, 79.46845293045044]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [234]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 2, 392, 30, 441, 77.38661766052246]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [235]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# []
# [['person', 9, 388, 40, 425, 84.72541570663452]]
# object 개수: 1
# ypoint_for_depth: [198]
# xpoint_for_depth: [232]
# 점 하나만 고려: 1 번째 object의 depth value:  49
# []
# [['person', 8, 387, 34, 433, 80.7235836982727]]
# object 개수: 1
# ypoint_for_depth: [197]
# xpoint_for_depth: [233]
# 점 하나만 고려: 1 번째 object의 depth value:  51
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3224d0fb738c> in <module>
#      42
#      43         # --- Getting frames and drawing
# ---> 44         kinect.get_frame(f)
#      45         kinect.get_color_frame()
#      46         image_np = kinect._frameRGB
#
# C:\tensorflow1\models\research\object_detection\acquisitionKinect.py in get_frame(self, frame)
#      81
#      82         # get shoulder rotations (yaw, pitch and roll in Euler angles)
# ---> 83         euler, quat = self.get_shoulder_angles()
#      84         if euler is None:
#      85             return
#
# C:\tensorflow1\models\research\object_detection\acquisitionKinect.py in get_shoulder_angles(self)
#     136
#     137         matrR = np.array([[N1.x, N1.y, N1.z, 0], [N2.x, N2.y, N2.z, 0], [N3.x, N3.y, N3.z, 0], [0, 0, 0, 1]])
# --> 138         quat = self.rotationMatrixToQuaternion(matrR)
#     139
#     140         return {"roll": shoulder_roll, "pitch": shoulder_pitch, "yaw": shoulder_yaw}, quat
#
# C:\tensorflow1\models\research\object_detection\acquisitionKinect.py in rotationMatrixToQuaternion(self, matrix, isprecise)
#     190                 q[k] = M[k, i] + M[i, k]
#     191                 q[3] = M[k, j] - M[j, k]
# --> 192             q *= 0.5 / math.sqrt(t * M[3, 3])
#     193         else:
#     194             m00 = M[0, 0]
#
# ValueError: math domain error
